# %% [markdown]
# <a href="https://colab.research.google.com/github/Griffinator123/Griffinator123/blob/main/feet_wet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import csv
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
# %matplotlib inline

# %%
penguins = sns.load_dataset("penguins")

# %%
penguins.tail(6)
# Out:
#     species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 338  Gentoo  Biscoe            47.2           13.7              214.0
# 339  Gentoo  Biscoe             NaN            NaN                NaN
# 340  Gentoo  Biscoe            46.8           14.3              215.0
# 341  Gentoo  Biscoe            50.4           15.7              222.0
# 342  Gentoo  Biscoe            45.2           14.8              212.0
# 343  Gentoo  Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 338       4925.0  Female
# 339          NaN     NaN
# 340       4850.0  Female
# 341       5750.0    Male
# 342       5200.0  Female
# 343       5400.0    Male

# %%
penguins.shape
# Out:
# (344, 7)

# %%
penguins.columns
# Out:
# Index(['species', 'island', 'bill_length_mm', 'bill_depth_mm',
#        'flipper_length_mm', 'body_mass_g', 'sex'],
#       dtype='object')

# %%
penguins.dtypes
# Out:
# species               object
# island                object
# bill_length_mm       float64
# bill_depth_mm        float64
# flipper_length_mm    float64
# body_mass_g          float64
# sex                   object
# dtype: object

# %%
fig, ax = plt.subplots()

sns.histplot(x=penguins['body_mass_g'])
fig.show()

# %%
fig, ax = plt.subplots()

sns.histplot(x=penguins['flipper_length_mm'])
fig.show()

# %%
fig, ax = plt.subplots()

sns.histplot(x=penguins['bill_depth_mm'])
fig.show()

# %%
penguins['body_mass_lb'] = penguins['body_mass_g']*.00220462

# %%
fig, ax = plt.subplots()

sns.histplot(x=penguins['body_mass_lb'],color='orange', edgecolor='red')
fig.show()

# %%
plt.figure()

sns.boxplot(data=penguins, x="species", y="body_mass_g",hue="sex")
plt.title('boxplot of body mass of species of penguins')
plt.xlabel('species')
plt.ylabel('Body Mass')
plt.show()

# %%
plt.figure

sns.violinplot(data=penguins, x="species",y = "body_mass_g")
# Out:
# <Axes: xlabel='species', ylabel='body_mass_g'>

# %%
plt.figure()

sns.boxplot(data=penguins, x="flipper_length_mm", y="island")
plt.title('boxplot of body mass of species of penguins')
plt.xlabel('species')
plt.ylabel('Body Mass')
plt.show()

# %%
plt.figure

sns.violinplot(data=penguins, x="flipper_length_mm",y = "island" ,hue="sex")
# Out:
# <Axes: xlabel='flipper_length_mm', ylabel='island'>

# %%
plt.figure()
sns.barplot(data=penguins, x="island", y="body_mass_g", hue+"sex")

plt.title('Body Mass of Penguis of Various Islands')
plt.xlabel('body mass in grams')
plt.ylabel('island')
plt.show()
# Out:
#   File "<ipython-input-59-098213f8fdaf>", line 2
#     sns.barplot(data=penguins, x="island", y="body_mass_g", hue+"sex")
#                                                                      ^
# SyntaxError: positional argument follows keyword argument

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_theme(style="dark")

# Simulate data from a bivariate Gaussian
n = 10000
mean = [0, 0]
cov = [(2, .4), (.4, .2)]
rng = np.random.RandomState(0)
x, y = rng.multivariate_normal(mean, cov, n).T

# Draw a combo histogram and scatterplot with density contours
f, ax = plt.subplots(figsize=(6, 6))
sns.scatterplot(x=x, y=y, s=5, color=".15")
sns.histplot(x=x, y=y, bins=50, pthresh=.1, cmap="mako")
sns.kdeplot(x=x, y=y, levels=5, color="w", linewidths=1)
# Out:
# <Axes: >

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

sns.set_theme(style="white")
rs = np.random.RandomState(50)

# Set up the matplotlib figure
f, axes = plt.subplots(3, 3, figsize=(9, 9), sharex=True, sharey=True)

# Rotate the starting point around the cubehelix hue circle
for ax, s in zip(axes.flat, np.linspace(0, 3, 10)):

    # Create a cubehelix colormap to use with kdeplot
    cmap = sns.cubehelix_palette(start=s, light=1, as_cmap=True)

    # Generate and plot a random bivariate dataset
    x, y = rs.normal(size=(2, 50))
    sns.kdeplot(
        x=x, y=y,
        cmap=cmap, fill=True,
        clip=(-5, 5), cut=10,
        thresh=0, levels=15,
        ax=ax,
    )
    ax.set_axis_off()

ax.set(xlim=(-3.5, 3.5), ylim=(-3.5, 3.5))
f.subplots_adjust(0, 0, 1, 1, .08, .08)
